# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('input_main.csv')

# %%
df.tail()
# Out:
#       Unnamed: 0      DEPTH         DT         GR    NPHI      RD    RHOB  \
# 1806        1806  3402.9396  60.265800  56.731800  0.1848  0.9691  2.4100
# 1807        1807  3403.0920  59.408001  57.055302  0.1851  1.0113  2.4137
# 1808        1808  3403.2444  58.550201  57.030899  0.1845  1.0631  2.4198
# 1809        1809  3403.3968  57.692501  57.006500  0.1839  1.1149  2.4259
# 1810        1810  3403.5492  56.836101  56.744999  0.1828  1.1589  2.4320
#
#         ROP5_RM      RS      RT     BVW   KLOGH    PHIF      SW     VCL  \
# 1806  17.283899  1.4278  1.6926  0.1146  4.8039  0.1725  0.6643  0.1564
# 1807  17.617599  1.3558  1.6324  0.1166  4.4631  0.1714  0.6805  0.1607
# 1808  18.044300  1.2827  1.5867  0.1183  4.0888  0.1691  0.6992  0.1604
# 1809  18.471001  1.2095  1.5410  0.1200  3.7459  0.1669  0.7188  0.1601
# 1810  18.913500  1.1944  1.5759  0.1186  3.4788  0.1644  0.7214  0.1566
#
#            pp_psi
# 1806  5355.864002
# 1807  5355.260818
# 1808  5353.959508
# 1809  5351.960071
# 1810  5349.262508

# %%
# selecting features and label
X = df.iloc[:, 1:-1]  # features
y = df.iloc[:,-1]  # label
X.shape, y.shape
# Out:
# ((1811, 14), (1811,))

# %%
# selecting features and label
X = df.iloc[:, 1:-1]  # features
y = df.iloc[:,-1]  # label
X.shape, y.shape
# Out:
# ((1811, 14), (1811,))

# %%
X
# Out:
#           DEPTH         DT         GR    NPHI         RD    RHOB    ROP5_RM  \
# 0     3127.7052  87.701897  28.952101  0.2170  38.960499  2.2082   6.301600
# 1     3127.8576  87.051201  29.013000  0.2168  40.557701  2.2143   6.347300
# 2     3128.0100  87.711700  29.101200  0.2166  42.197201  2.2200   6.396400
# 3     3128.1624  87.745697  29.576700  0.2178  44.440498  2.2200   6.493900
# 4     3128.3148  88.152100  30.052200  0.2190  46.683899  2.2200   6.591500
# ...         ...        ...        ...     ...        ...     ...        ...
# 1806  3402.9396  60.265800  56.731800  0.1848   0.969100  2.4100  17.283899
# 1807  3403.0920  59.408001  57.055302  0.1851   1.011300  2.4137  17.617599
# 1808  3403.2444  58.550201  57.030899  0.1845   1.063100  2.4198  18.044300
# 1809  3403.3968  57.692501  57.006500  0.1839   1.114900  2.4259  18.471001
# 1810  3403.5492  56.836101  56.744999  0.1828   1.158900  2.4320  18.913500
#
#               RS          RT     BVW       KLOGH    PHIF      SW     VCL
# 0      95.438400  130.219100  0.0195  733.528686  0.2483  0.0785  0.1245
# 1     103.421096  127.670898  0.0196  695.894897  0.2461  0.0797  0.1251
# 2     110.710601  125.064598  0.0197  658.749694  0.2441  0.0809  0.1260
# 3     108.128898  121.629501  0.0200  604.472290  0.2445  0.0818  0.1305
# 4     105.547302  118.194396  0.0203  554.666870  0.2450  0.0827  0.1351
# ...          ...         ...     ...         ...     ...     ...     ...
# 1806    1.427800    1.692600  0.1146    4.803900  0.1725  0.6643  0.1564
# 1807    1.355800    1.632400  0.1166    4.463100  0.1714  0.6805  0.1607
# 1808    1.282700    1.586700  0.1183    4.088800  0.1691  0.6992  0.1604
# 1809    1.209500    1.541000  0.1200    3.745900  0.1669  0.7188  0.1601
# 1810    1.194400    1.575900  0.1186    3.478800  0.1644  0.7214  0.1566
#
# [1811 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_whole_scaled=scaler.transform(X)

# %%
X
# Out:
#           DEPTH         DT         GR    NPHI         RD    RHOB    ROP5_RM  \
# 0     3127.7052  87.701897  28.952101  0.2170  38.960499  2.2082   6.301600
# 1     3127.8576  87.051201  29.013000  0.2168  40.557701  2.2143   6.347300
# 2     3128.0100  87.711700  29.101200  0.2166  42.197201  2.2200   6.396400
# 3     3128.1624  87.745697  29.576700  0.2178  44.440498  2.2200   6.493900
# 4     3128.3148  88.152100  30.052200  0.2190  46.683899  2.2200   6.591500
# ...         ...        ...        ...     ...        ...     ...        ...
# 1806  3402.9396  60.265800  56.731800  0.1848   0.969100  2.4100  17.283899
# 1807  3403.0920  59.408001  57.055302  0.1851   1.011300  2.4137  17.617599
# 1808  3403.2444  58.550201  57.030899  0.1845   1.063100  2.4198  18.044300
# 1809  3403.3968  57.692501  57.006500  0.1839   1.114900  2.4259  18.471001
# 1810  3403.5492  56.836101  56.744999  0.1828   1.158900  2.4320  18.913500
#
#               RS          RT     BVW       KLOGH    PHIF      SW     VCL
# 0      95.438400  130.219100  0.0195  733.528686  0.2483  0.0785  0.1245
# 1     103.421096  127.670898  0.0196  695.894897  0.2461  0.0797  0.1251
# 2     110.710601  125.064598  0.0197  658.749694  0.2441  0.0809  0.1260
# 3     108.128898  121.629501  0.0200  604.472290  0.2445  0.0818  0.1305
# 4     105.547302  118.194396  0.0203  554.666870  0.2450  0.0827  0.1351
# ...          ...         ...     ...         ...     ...     ...     ...
# 1806    1.427800    1.692600  0.1146    4.803900  0.1725  0.6643  0.1564
# 1807    1.355800    1.632400  0.1166    4.463100  0.1714  0.6805  0.1607
# 1808    1.282700    1.586700  0.1183    4.088800  0.1691  0.6992  0.1604
# 1809    1.209500    1.541000  0.1200    3.745900  0.1669  0.7188  0.1601
# 1810    1.194400    1.575900  0.1186    3.478800  0.1644  0.7214  0.1566
#
# [1811 rows x 14 columns]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

# %%
y
# Out:
# 0       4641.506076
# 1       4641.825160
# 2       4642.428943
# 3       4643.317427
# 4       4644.490611
#            ...
# 1806    5355.864002
# 1807    5355.260818
# 1808    5353.959508
# 1809    5351.960071
# 1810    5349.262508
# Name: pp_psi, Length: 1811, dtype: float64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ## PCA WITH RF

# %%
import time

# %%
def convert(seconds):
    seconds = seconds % (24 * 3600)
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60
    return "%d:%02d:%02d" % (hour, minutes, seconds)

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
import time
from sklearn.ensemble  import RandomForestRegressor

# %%
pca = PCA(n_components=4)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)
X_whole_pca = pca.transform(X_whole_scaled)

# %%
regr = GridSearchCV(
    RandomForestRegressor(random_state=2), 
    {
        
        'n_estimators': [200,300,400],
        'criterion': ['squared_error','absolute_error'],
        'max_depth': [6,8,10],
        #'max_features': ['sqrt', 'log2', None],
        #'min_samples_split': [2,3,4,5],
        # 'min_weight_fraction_leaf': [0, 1,2,3],
        # 'max_leaf_nodes': [1,2,3,4,5],
    }, 
    cv=5, 
    scoring=['neg_mean_squared_error', 'r2'], 
    refit='r2',
    verbose=2)

start = time.time()

regr.fit(X_train_pca, y_train)

end = time.time()

print('run_time:', convert(end-start), 'h:m:s')
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END criterion=squared_error, max_depth=6, n_estimators=200; total time=   3.4s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=200; total time=   3.8s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=200; total time=   3.2s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=200; total time=   3.9s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=200; total time=   3.8s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=300; total time=   4.7s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=300; total time=   4.9s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=300; total time=   5.9s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=300; total time=   5.2s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=300; total time=   5.4s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=400; total time=   7.2s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=400; total time=   7.8s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=400; total time=   6.2s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=400; total time=   6.9s
# [CV] END criterion=squared_error, max_depth=6, n_estimators=400; total time=   6.6s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=200; total time=   4.0s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=200; total time=   3.8s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=200; total time=   4.8s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=200; total time=   4.3s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=200; total time=   4.1s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=300; total time=   6.7s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=300; total time=   6.9s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=300; total time=   7.2s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=300; total time=   7.4s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=300; total time=   7.2s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=400; total time=   9.0s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=400; total time=   7.8s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=400; total time=   8.3s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=400; total time=   8.3s
# [CV] END criterion=squared_error, max_depth=8, n_estimators=400; total time=   8.8s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=200; total time=   5.8s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=200; total time=   5.2s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=200; total time=   5.1s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=200; total time=   5.1s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=200; total time=   5.1s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=300; total time=   8.1s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=300; total time=   7.1s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=300; total time=   7.9s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=300; total time=   9.9s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=300; total time=  10.8s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=400; total time=  12.0s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=400; total time=  11.6s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=400; total time=  12.3s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=400; total time=  10.8s
# [CV] END criterion=squared_error, max_depth=10, n_estimators=400; total time=  10.5s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=200; total time=  14.3s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=200; total time=  15.1s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=200; total time=  17.6s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=200; total time=  16.3s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=200; total time=  14.9s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=300; total time=  23.9s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=300; total time=  26.8s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=300; total time=  28.2s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=300; total time=  27.6s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=300; total time=  33.3s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=400; total time=  39.6s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=400; total time=  38.7s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=400; total time=  37.1s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=400; total time=  41.1s
# [CV] END criterion=absolute_error, max_depth=6, n_estimators=400; total time=  38.0s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=200; total time=  20.5s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=200; total time=  20.0s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=200; total time=  15.2s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=200; total time=  15.9s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=200; total time=  15.4s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=300; total time=  22.2s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=300; total time=  24.2s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=300; total time=  22.3s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=300; total time=  23.7s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=300; total time=  22.2s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=400; total time=  30.5s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=400; total time=  27.9s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=400; total time=  27.4s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=400; total time=  28.4s
# [CV] END criterion=absolute_error, max_depth=8, n_estimators=400; total time=  26.9s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=200; total time=  18.6s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=200; total time=  21.7s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=200; total time=  23.8s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=200; total time=  18.4s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=200; total time=  17.4s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=300; total time=  23.8s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=300; total time=  25.1s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=300; total time=  24.3s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=300; total time=  26.4s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=300; total time=  24.7s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=400; total time=  39.8s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=400; total time=  37.2s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=400; total time=  33.9s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=400; total time=  35.2s
# [CV] END criterion=absolute_error, max_depth=10, n_estimators=400; total time=  39.6s
# run_time: 0:24:45 h:m:s

# %%
print(regr.best_params_)

print(regr.best_score_)
# Out:
# {'criterion': 'squared_error', 'max_depth': 10, 'n_estimators': 200}
# 0.8793663824451242

# %%
# Predictions
pred_2 = regr.predict(X_test_pca)
pred_1 = regr.predict(X_train_pca)
pred_3=  regr.predict(X_whole_pca)

# %%
import os

# Create the output/cnn directory if it doesn't exist
output_dir = "./output/rf_regressor_PCA_4"
os.makedirs(output_dir, exist_ok=True)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, max_error

# Calculate additional metrics
train_rmse = np.sqrt(mean_squared_error(y_train, pred_1))
test_rmse = np.sqrt(mean_squared_error(y_test, pred_2))

# Calculate other metrics as before
train_r2 = r2_score(y_train, pred_1)
train_mae = mean_absolute_error(y_train, pred_1)
train_mse = mean_squared_error(y_train, pred_1)
train_mape = mean_absolute_percentage_error(y_train, pred_1)
train_maxE = max_error(y_train, pred_1)
train_minE = min(abs(y_train - pred_1))

test_r2 = r2_score(y_test, pred_2)
test_mae = mean_absolute_error(y_test, pred_2)
test_mse = mean_squared_error(y_test, pred_2)
test_mape = mean_absolute_percentage_error(y_test, pred_2)
test_maxE = max_error(y_test, pred_2)
test_minE = min(abs(y_test - pred_2))

# Create a dictionary for metrics
metrics = {
    'performance_metrics': ['R2', 'MAE', 'MSE', 'RMSE', 'MAPE', 'maxE', 'minE'],
    'training': [train_r2, train_mae, train_mse, train_rmse, train_mape, train_maxE, train_minE],
    'testing': [test_r2, test_mae, test_mse, test_rmse, test_mape, test_maxE, test_minE]
}

# Create a DataFrame from the metrics dictionary
performance_metrics = pd.DataFrame(metrics)
performance = performance_metrics.transpose()

# Save the performance metrics to a CSV file
performance.to_csv("./output/rf_regressor_PCA_4/performance_result_metrics_GCV.csv")

# Display the performance metrics DataFrame
performance
# Out:
#                             0          1            2          3         4  \
# performance_metrics        R2        MAE          MSE       RMSE      MAPE
# training             0.965222  17.192844  1149.853417  33.909489  0.003509
# testing              0.917227  27.256702  2803.301567  52.946214  0.005548
#
#                               5         6
# performance_metrics        maxE      minE
# training             331.721364  0.000415
# testing              387.351641  0.006742

# %%
a = np.stack([y_train, pred_1], axis=1) # training
a = pd.DataFrame(a, columns=['y_train', 'y_train_pred'])

b = np.stack([y_test, pred_2], axis=1) # testing 
b = pd.DataFrame(b, columns=['y_test', 'y_test_pred'])

c= np.stack([y, pred_3], axis=1) # testing 
c = pd.DataFrame(c, columns=['y', 'y_pred'])

with pd.ExcelWriter("./output/rf_regressor_PCA_4/predicted_CATBOOST_model_GCV.xlsx") as writer:
    # use to_excel function and specify the sheet_name and index
    # to store the dataframe in specified sheet
    a.to_excel(writer, sheet_name="training", index=True)
    b.to_excel(writer, sheet_name="testing", index=True)
    c.to_excel(writer, sheet_name="whole_data", index=True)

# %%
df = pd.DataFrame.from_dict(regr.best_params_, orient='index', columns=['Best Value'])

result = df[['Best Value']]


result.to_csv('./output/rf_regressor_PCA_4/best_param_result_for_random_forest_GCV.csv', index_label='Parameter')

print(result)
# Out:
#                  Best Value
# criterion     squared_error
# max_depth                10
# n_estimators            200

# %%
# converting the results to a readable format using dataFrame
df = pd.DataFrame(regr.cv_results_)

# Getting all parameter combinations and their performance results
result = df[['param_n_estimators', 'param_criterion', 'param_max_depth',
              'mean_test_r2','mean_test_neg_mean_squared_error']]

# Save the results to a CSV file
result.to_csv('./output/rf_regressor_PCA_4/performance_result_for_random_forest_GCV.csv', index=False)

# Display the results
print(result)
# Out:
#    param_n_estimators param_criterion param_max_depth  mean_test_r2  \
# 0                 200   squared_error               6      0.836473
# 1                 300   squared_error               6      0.836309
# 2                 400   squared_error               6      0.836136
# 3                 200   squared_error               8      0.865831
# 4                 300   squared_error               8      0.865674
# 5                 400   squared_error               8      0.865367
# 6                 200   squared_error              10      0.879366
# 7                 300   squared_error              10      0.878949
# 8                 400   squared_error              10      0.878791
# 9                 200  absolute_error               6      0.850799
# 10                300  absolute_error               6      0.851529
# 11                400  absolute_error               6      0.851104
# 12                200  absolute_error               8      0.869823
# 13                300  absolute_error               8      0.869828
# 14                400  absolute_error               8      0.869882
# 15                200  absolute_error              10      0.877922
# 16                300  absolute_error              10      0.877369
# 17                400  absolute_error              10      0.877428
#
#     mean_test_neg_mean_squared_error
# 0                       -5365.328441
# 1                       -5372.403658
# 2                       -5378.053425
# 3                       -4391.299509
# 4                       -4398.716209
# 5                       -4407.966540
# 6                       -3945.245846
# 7                       -3959.614813
# 8                       -3964.066546
# 9                       -4888.639164
# 10                      -4862.265562
# 11                      -4876.264706
# 12                      -4262.758602
# 13                      -4260.740459
# 14                      -4258.797453
# 15                      -3996.626025
# 16                      -4013.736720
# 17                      -4011.403811

# %%
pred_2 = regr.predict(X_test_pca)
pred_1 = regr.predict(X_train_pca)
pred_3=  regr.predict(X_whole_pca)

# %%
#from sklearn.externals import joblib
from joblib import dump, load
dump(regr, './output/rf_regressor_PCA_4/trained_rf_regressor.joblib')

#clf = load('trained_linear_regression_model.joblib')
# Out:
# ['./output/rf_regressor_PCA_4/trained_rf_regressor.joblib']

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score


train_residuals = y_train - pred_1
test_residuals = y_test - pred_2

fig, ax = plt.subplots(figsize=(8, 6))


ax.scatter(pred_1, train_residuals, c='blue', label=f'Train Residuals (R^2 = {train_r2:.2f})')

ax.scatter(pred_2, test_residuals, c='red', label=f'Test Residuals (R^2 = {test_r2:.2f})')


ax.legend()


ax.set_xlabel('Predicted Values')
ax.set_ylabel('Residuals')
ax.set_title('Residual Plot')


ax.grid(True)

plt.savefig('./output/rf_regressor_PCA_4/residual_plot.png', dpi=300)
plt.tight_layout()
